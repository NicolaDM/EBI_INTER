# %% [markdown]
# ## <center>Preparing data for the Venn diagram.</center>
#
#
# | **Label** | **start time** | **finish time** | **last modified** |
# |:--------------:|:-----------:|:-----------:|:----------------:|
# |   Project 1   |  2023-07-10 |  2023-07-19 |   2023-07-19     |
#
# ####  Threshold:
# - SB > 0,
# - coverage ratio < 0.1,
# - AF > 0.001.

# %% [markdown]
# ====================== Info ======================
# Total number of positions:  4033264429
# nb_SB_PASSED:  1782985
# nb_AF_PASSED:  7547094
# nb_COV_PASSED:  583535685
# ====================== Info ======================
# both_PASSED:  377289
# both_UNPASSED:  3420841838
# ====================== Info ======================
# nb_AF_SB_PASSED:  17971522
# nb_SB_COV_PASSED:  253433
# nb_AF_COV_PASSED:  954583

# %%
same_count = 4033264429
Flag_SB_PASSED = 1782985
Flag_AF_PASSED = 7547094
Flag_COV_PASSED = 583535685
both_PASSED = 377289
both_UNPASSED = 3420841838
Flag_SB_Flag_AF_PASSED = 17971522
Flag_SB_Flag_COV_PASSED = 253433
Flag_AF_Flag_COV_PASSED = 954583

pass_1 = Flag_SB_PASSED+Flag_AF_PASSED+Flag_COV_PASSED
pass_2 = Flag_SB_Flag_AF_PASSED+Flag_SB_Flag_COV_PASSED+Flag_AF_Flag_COV_PASSED
pass_3 = both_PASSED + both_UNPASSED
nb_pass = pass_1+pass_2+pass_3

print(round(both_UNPASSED/nb_pass*100,3),'%')
print('=======================================')

print(round(Flag_AF_PASSED/nb_pass*100,3),'%')
print(round(Flag_COV_PASSED/nb_pass*100,3),'%')
print(round(Flag_SB_PASSED/nb_pass*100,3),'%')
print('=======================================')

print(round(Flag_SB_Flag_AF_PASSED/nb_pass*100,3),'%')
print(round(Flag_SB_Flag_COV_PASSED/nb_pass*100,3),'%')
print(round(Flag_AF_Flag_COV_PASSED/nb_pass*100,3),'%')

print('=======================================')
print(round(both_PASSED/nb_pass*100,3),'%')
# Out:
# 84.816 %
# ...
# 0.187 %
# 14.468 %
# 0.044 %
# ...
# 0.446 %
# 0.006 %
# 0.024 %
# ...
# 0.009 %

# %%
import pandas as pd

Folder_path = "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/folderData_mergeINFO/ERR7029343_merged.txt"
df_v0 = pd.read_csv(Folder_path, sep='\t')

# 创建 "Label" 列并设置相应的值
df_v0["Label_COV"] = (df_v0["RATIO"] < 0.1).astype(int)
df_v0["Label_AF"] = (df_v0["AF"] > 0.001).astype(int)
df_v0["Label_SB"] = (df_v0["SB"] > 0).astype(int)

df_v0
# Out:
#        Position  RATIO   AF  SB  Label_COV  Label_AF  Label_SB
# 0             1    0.0  0.0   0          1         0         0
# 1             2    0.0  0.0   0          1         0         0
# 2             3    0.0  0.0   0          1         0         0
# 3             4    0.0  0.0   0          1         0         0
# 4             5    0.0  0.0   0          1         0         0
# ...         ...    ...  ...  ..        ...       ...       ...
# 29898     29899    0.0  0.0   0          1         0         0
# 29899     29900    0.0  0.0   0          1         0         0
# 29900     29901    0.0  0.0   0          1         0         0
# 29901     29902    0.0  0.0   0          1         0         0
# 29902     29903    0.0  0.0   0          1         0         0
#
# [29903 rows x 7 columns]

# %%
# positions that were masked/ambiguous in the assemblies.
print('Count: ', len(df_v0))

print('COV: ', 
      sum((df_v0['Label_COV'] == 1)&(df_v0['Label_AF'] == 0)&(df_v0['Label_SB'] == 0)))
print('AF: ', 
      sum((df_v0['Label_COV'] == 0)&(df_v0['Label_AF'] == 1)&(df_v0['Label_SB'] == 0)))
print('SB: ', 
      sum((df_v0['Label_COV'] == 0)&(df_v0['Label_AF'] == 0)&(df_v0['Label_SB'] == 1)))
# Out:
# Count:  29903
# COV:  8683
# AF:  45
# SB:  14

# %%
# positions that were masked/ambiguous in the assemblies.
print('AF-SB: ', 
      sum((df_v0['Label_COV'] == 0)&(df_v0['Label_AF'] == 1)&(df_v0['Label_SB'] == 1)))
print('SB-COV: ', 
      sum((df_v0['Label_COV'] == 1)&(df_v0['Label_AF'] == 0)&(df_v0['Label_SB'] == 1)))
print('COV-AF: ', 
      sum((df_v0['Label_COV'] == 1)&(df_v0['Label_AF'] == 1)&(df_v0['Label_SB'] == 0)))

print('AF-SB-COV: ', 
      sum((df_v0['Label_COV'] == 1)&(df_v0['Label_AF'] == 1)&(df_v0['Label_SB'] == 1)))
print('un_AF-SB-COV: ', 
      sum((df_v0['Label_COV'] == 0)&(df_v0['Label_AF'] == 0)&(df_v0['Label_SB'] == 0)))
# Out:
# AF-SB:  26
# SB-COV:  7
# COV-AF:  3
# AF-SB-COV:  1
# un_AF-SB-COV:  21124

# %% [markdown]
# ## Test - Final version

# %%
import os
import pandas as pd

# ==================Requires modification==================
# folder_path: The folders for ANNOT information and COV information were merged in the previous step.
# ==================Requires modification==================

def process_files(folder_path):
    nb_count = 0
    nb_SB_PASSED = 0
    nb_AF_PASSED = 0
    nb_COV_PASSED = 0
    both_PASSED = 0
    both_UNPASSED = 0
    nb_AF_SB_PASSED = 0
    nb_SB_COV_PASSED = 0
    nb_AF_COV_PASSED = 0

    for file_name in os.listdir(folder_path):
        if file_name.endswith(".txt"):
            df_v0 = pd.read_csv(os.path.join(folder_path, file_name), sep='\t')
            
            df_v0["Label_COV"] = (df_v0["RATIO"] < 0.1).astype(int)
            df_v0["Label_AF"] = (df_v0["AF"] > 0.001).astype(int)
            df_v0["Label_SB"] = (df_v0["SB"] > 0).astype(int)
            
            nb_count += len(df_v0)
            nb_SB_PASSED += sum((df_v0['Label_COV'] == 0)&(df_v0['Label_AF'] == 0)&(df_v0['Label_SB'] == 1))
            nb_AF_PASSED += sum((df_v0['Label_COV'] == 0)&(df_v0['Label_AF'] == 1)&(df_v0['Label_SB'] == 0))
            nb_COV_PASSED += sum((df_v0['Label_COV'] == 1)&(df_v0['Label_AF'] == 0)&(df_v0['Label_SB'] == 0))
            
            both_PASSED += sum((df_v0['Label_COV'] == 1)&(df_v0['Label_AF'] == 1)&(df_v0['Label_SB'] == 1))
            both_UNPASSED += sum((df_v0['Label_COV'] == 0)&(df_v0['Label_AF'] == 0)&(df_v0['Label_SB'] == 0))
            nb_AF_SB_PASSED += sum((df_v0['Label_COV'] == 0)&(df_v0['Label_AF'] == 1)&(df_v0['Label_SB'] == 1))
            nb_SB_COV_PASSED += sum((df_v0['Label_COV'] == 1)&(df_v0['Label_AF'] == 0)&(df_v0['Label_SB'] == 1))
            nb_AF_COV_PASSED += sum((df_v0['Label_COV'] == 1)&(df_v0['Label_AF'] == 1)&(df_v0['Label_SB'] == 0))

    print('====================== Info ======================')
    print('Total number of positions: ', nb_count)
    print('nb_SB_PASSED: ', nb_SB_PASSED)
    print('nb_AF_PASSED: ', nb_AF_PASSED)
    print('nb_COV_PASSED: ', nb_COV_PASSED)
    print('====================== Info ======================')
    print('both_PASSED: ', both_PASSED)
    print('both_UNPASSED: ', both_UNPASSED)
    print('====================== Info ======================')
    print('nb_AF_SB_PASSED: ', nb_AF_SB_PASSED)
    print('nb_SB_COV_PASSED: ', nb_SB_COV_PASSED)
    print('nb_AF_COV_PASSED: ', nb_AF_COV_PASSED)

folder_path = "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/folderData_mergeINFO"
process_files(folder_path)
# Out:
# ====================== Info ======================
# Total masked positions in Virdian assembly (excludes Colman's):  19070
# Total positions in Colman assembly (excludes Virdian's):  168689
# Total positions masked in both assemblies:  43755
# ====================== Info ======================
# Total unmasked positions in Virdian assembly, without errors identified by MAPLE:  2927438
# Total unmasked positions in Colman assembly, without errors identified by MAPLE:  2777767
# ====================== Info ======================
# Total positions in Virdian assembly identified as errors by MAPLE (excludes Colman's errors):  11
# Total positions in Colman assembly identified as errors by MAPLE (excludes Virdian's errors):  63
# Total positions identified as errors in both assemblies by MAPLE:  26

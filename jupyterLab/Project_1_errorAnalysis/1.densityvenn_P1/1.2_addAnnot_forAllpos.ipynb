# %%
import pandas as pd
Folder_path = "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/folderData_MAPLE_allPos/ERR7875743_coverage.txt"
df_v0 = pd.read_csv(Folder_path, sep='\t')
df_v0
# Out:
#        Position   N  RATIO
# 0             1  A     0.0
# 1             2  T     0.0
# 2             3  T     0.0
# 3             4  A     0.0
# 4             5  A     0.0
# ...         ...  ..    ...
# 29898     29899  A     0.0
# 29899     29900  A     0.0
# 29900     29901  A     0.0
# 29901     29902  A     0.0
# 29902     29903  A     0.0
#
# [29903 rows x 3 columns]

# %%
Folder_path = "/nfs/research/goldman/zihao/Datas/p1/File_5_annot/New_Decompress/ERR7875743_annot.txt"
df_v0 = pd.read_csv(Folder_path, sep='\t')
df_v0
# Out:
#          POS  REF  ALT   AF  SB
# 0          1  NaN  NaN  0.0   0
# 1          2  NaN  NaN  0.0   0
# 2          3  NaN  NaN  0.0   0
# 3          4  NaN  NaN  0.0   0
# 4          5  NaN  NaN  0.0   0
# ...      ...  ...  ...  ...  ..
# 29898  29899  NaN  NaN  0.0   0
# 29899  29900  NaN  NaN  0.0   0
# 29900  29901  NaN  NaN  0.0   0
# 29901  29902  NaN  NaN  0.0   0
# 29902  29903  NaN  NaN  0.0   0
#
# [29903 rows x 5 columns]

# %%
import os
import pandas as pd

def merge_files(folder1_path, folder2_path, output_folder_path):
    # If output_folder_path doesn't exist, create it
    if not os.path.exists(output_folder_path):
        os.makedirs(output_folder_path)

    not_found_ids = []

    # Iterate through files in Folder1
    for filename in os.listdir(folder1_path):
        if filename.endswith("_coverage.txt"):
            file_id = filename.replace("_coverage.txt", "")
            filepath1 = os.path.join(folder1_path, filename)

            # Confirm if corresponding file exists in Folder2
            filepath2 = os.path.join(folder2_path, f"{file_id}_annot.txt")
            if not os.path.exists(filepath2):
                not_found_ids.append(file_id)
                continue

            # Load the two files into dataframes
            df1 = pd.read_csv(filepath1, sep="\t")
            df2 = pd.read_csv(filepath2, sep="\t")

            # Merge based on the 'Position' column from df1 and 'POS' column from df2
            df_merged = pd.merge(df1, df2, left_on="Position", right_on="POS", how="inner")[['Position','RATIO','AF','SB']]

            # Save the merged data to a new file
            output_filepath = os.path.join(output_folder_path, f"{file_id}_merged.txt")
            df_merged.to_csv(output_filepath, sep="\t", index=False)

    # Output IDs not found
    not_found_ids_file = os.path.join(output_folder_path, "not_found_ids.txt")
    with open(not_found_ids_file, "w") as f:
        for id_ in not_found_ids:
            f.write(f"{id_}\n")

folder1_path = "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/folderData_test"
# "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/folderData_MAPLE_allPos"
folder2_path = "/nfs/research/goldman/zihao/Datas/p1/File_5_annot/New_Decompress"
output_folder_path = "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/folderData_mergeINFO"  # 请填入你需要保存结果文件的文件夹路径


merge_files(folder1_path, folder2_path, output_folder_path)

# %% [markdown]
# ### Final
# ```python
# /nfs/research/goldman/zihao/N_errorsProject_1_P1/Folder_allPos_dataProcessing/CODE_allPos_vennAnnot.py
# ```
# ```python
# import os
# import pandas as pd
#
# # ==================Requires modification==================
# # folder1_path: The file of the COV obtained in the previous step
# # folder2_path: Documents containing ANNOT information
# # output_folder_path: Folders where merged files will be stored
# # output_folderMissing_path: Folders where files with missing IDs will be stored
# # ==================Requires modification==================
#
# def merge_files(folder1_path, folder2_path, output_folder_path, output_folderMissing_path):
#     # If output_folder_path doesn't exist, create it
#     if not os.path.exists(output_folder_path):
#         os.makedirs(output_folder_path)
#
#     not_found_ids = []
#
#     # Iterate through files in Folder1
#     for filename in os.listdir(folder1_path):
#         if filename.endswith("_coverage.txt"):
#             file_id = filename.replace("_coverage.txt", "")
#             filepath1 = os.path.join(folder1_path, filename)
#
#             # Confirm if corresponding file exists in Folder2
#             filepath2 = os.path.join(folder2_path, f"{file_id}_annot.txt")
#             if not os.path.exists(filepath2):
#                 not_found_ids.append(file_id)
#                 continue
#
#             # Load the two files into dataframes
#             df1 = pd.read_csv(filepath1, sep="\t")
#             df2 = pd.read_csv(filepath2, sep="\t")
#
#             # Merge based on the 'Position' column from df1 and 'POS' column from df2
#             df_merged = pd.merge(df1, df2, left_on="Position", right_on="POS", how="inner")[['Position','RATIO','AF','SB']]
#
#             # Save the merged data to a new file
#             output_filepath = os.path.join(output_folder_path, f"{file_id}_merged.txt")
#             df_merged.to_csv(output_filepath, sep="\t", index=False)
#
#     # Output IDs not found
#     not_found_ids_file = os.path.join(output_folderMissing_path, "not_found_ids.txt")
#     with open(not_found_ids_file, "w") as f:
#         for id_ in not_found_ids:
#             f.write(f"{id_}\n")
#
# folder1_path = "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/folderData_MAPLE_allPos"
# folder2_path = "/nfs/research/goldman/zihao/Datas/p1/File_5_annot/New_Decompress"
# output_folderMissing_path = "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/Folder_missingID"
# output_folder_path = "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/folderData_mergeINFO"
#
#
# merge_files(folder1_path, folder2_path, output_folder_path, output_folderMissing_path)
#
#
# def count_files(folder_path):
#     if not os.path.isdir(folder_path):
#         raise ValueError("Invalid folder path!")
#
#     file_count = 0
#     for _, _, files in os.walk(folder_path):
#         file_count += len(files)
#
#     return file_count
#
# folder_path = output_folder_path
#
# try:
#     num_files = count_files(folder_path)
#     print('=========================== information =========================== ')
#     print(f"The number of samples is: {num_files}")
# except ValueError as e:
#     print(str(e))
#
#
# ```

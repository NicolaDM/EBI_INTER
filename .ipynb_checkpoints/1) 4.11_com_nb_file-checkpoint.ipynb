# %%
import pandas as pd
import urllib.request
import os
# import gzip

# %%
df = pd.read_csv('../Datas/analysis_run_list.txt', delimiter='\t')
df.head()
# Out:
#       run_id  number of files
# 0  DRR286879                3
# 1  DRR286880                3
# 2  DRR286881                3
# 3  DRR286882                3
# 4  DRR286883                3

# %%
df[df['number of files']==5]
# Out:
#               run_id  number of files
# 126        DRR428582                5
# 127      ERR10008306                5
# 128      ERR10008309                5
# 129      ERR10008311                5
# 130      ERR10008328                5
# ...              ...              ...
# 2252834  SRR23816735                5
# 2252835  SRR23816736                5
# 2252836  SRR23816737                5
# 2252837  SRR23816738                5
# 2252838  SRR23816739                5
#
# [508680 rows x 2 columns]

# %%
# 读取文件
df_2 = pd.read_csv('../Datas/analysis_full_06.04.23.txt', delimiter='\t', nrows=1000000)
df_2.head()
# Out:
#       run_id                     data_file analysis_id
# 0  DRR286879     DRR286879_filtered.vcf.gz  ERZ6074381  \
# 1  DRR286879       DRR286879_output.tar.gz  ERZ6078684
# 2  DRR286879  DRR286879_consensus.fasta.gz  ERZ8484270
# 3  DRR286880       DRR286880_output.tar.gz  ERZ6081086
# 4  DRR286880     DRR286880_filtered.vcf.gz  ERZ6067986
#
#                                             FTP_path
# 0  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ607/ERZ6074381...
# 1  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ607/ERZ6078684...
# 2  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ848/ERZ8484270...
# 3  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ608/ERZ6081086...
# 4  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ606/ERZ6067986...

# %%
df_merge_right = pd.merge(df, df_2, on='run_id', how='right')  # 右连接
df_merge_right.head()
# Out:
#       run_id  number of files                     data_file analysis_id
# 0  DRR286879                3     DRR286879_filtered.vcf.gz  ERZ6074381  \
# 1  DRR286879                3       DRR286879_output.tar.gz  ERZ6078684
# 2  DRR286879                3  DRR286879_consensus.fasta.gz  ERZ8484270
# 3  DRR286880                3       DRR286880_output.tar.gz  ERZ6081086
# 4  DRR286880                3     DRR286880_filtered.vcf.gz  ERZ6067986
#
#                                             FTP_path
# 0  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ607/ERZ6074381...
# 1  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ607/ERZ6078684...
# 2  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ848/ERZ8484270...
# 3  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ608/ERZ6081086...
# 4  ftp://ftp.sra.ebi.ac.uk/vol1/ERZ606/ERZ6067986...

# %%
df_merge_right_v1 = df_merge_right[df_merge_right["number of files"] == 5] #5

# %%
df_merge_right_v1.head()
# Out:
# Empty DataFrame
# Columns: [run_id, number of files, data_file, analysis_id, FTP_path]
# Index: []

# %%
df_merge_right_v1.to_csv('../Datas/nb_5.txt', sep='\t', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_merge_right_v1.to_csv('../Datas/nb_5.txt', sep='\t', index=False)
#
# File ~/anaconda3/envs/inter/lib/python3.9/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/anaconda3/envs/inter/lib/python3.9/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/envs/inter/lib/python3.9/site-packages/pandas/io/formats/csvs.py:259, in CSVFormatter.save(self)
#     240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#    (...)
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
# --> 259     self._save()
#
# File ~/anaconda3/envs/inter/lib/python3.9/site-packages/pandas/io/formats/csvs.py:264, in CSVFormatter._save(self)
#     262 if self._need_to_save_header:
#     263     self._save_header()
# --> 264 self._save_body()
#
# File ~/anaconda3/envs/inter/lib/python3.9/site-packages/pandas/io/formats/csvs.py:302, in CSVFormatter._save_body(self)
#     300 if start_i >= end_i:
#     301     break
# --> 302 self._save_chunk(start_i, end_i)
#
# File ~/anaconda3/envs/inter/lib/python3.9/site-packages/pandas/io/formats/csvs.py:313, in CSVFormatter._save_chunk(self, start_i, end_i)
#     310 data = [res.iget_values(i) for i in range(len(res.items))]
#     312 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 313 libwriters.write_csv_rows(
#     314     data,
#     315     ix,
#     316     self.nlevels,
#     317     self.cols,
#     318     self.writer,
#     319 )
#
# File ~/anaconda3/envs/inter/lib/python3.9/site-packages/pandas/_libs/writers.pyx:72, in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %% [markdown]
# # Download

# %%
df_merge_right_v1 = df_merge_right_v1[['FTP_path']]

# %%
# Specify the folder path
folder_path = '../Folder/'

# Create the folder if it does not exist
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    
# Iterate through each row and download the file
for index, row in df_merge_right_v1.iterrows():
    ftp_path = row['FTP_path']
    file_name = ftp_path.split('/')[-1]
    file_path = os.path.join(folder_path, file_name)
    urllib.request.urlretrieve(ftp_path, file_path)

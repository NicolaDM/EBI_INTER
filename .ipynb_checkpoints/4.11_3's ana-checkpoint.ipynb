# %%
import pandas as pd
import gzip

# %%
# 读取文件
df = pd.read_csv('../Datas/analysis_full_06.04.23.txt', delimiter='\t', nrows=10)

# %%
pd.set_option('display.max_colwidth', None)
df

# %%
# 定义vcf文件路径
vcf_file = '../Folder/DRR286879_filtered.vcf.gz'

# 使用gzip库打开压缩的vcf文件并读取
with gzip.open(vcf_file, 'rt') as f:
    # 跳过以##开头的注释行
    lines = [line for line in f if not line.startswith('##')]
    # 获取以#开头的标题行
    header = lines[0].strip().split('\t')
    # 读取剩下的数据行
    data = [line.strip().split('\t') for line in lines[1:]]

# 将数据转换为pandas DataFrame
df = pd.DataFrame(data, columns=header)



# 打印DataFrame
df
# Out:
#         #CHROM    POS ID REF ALT   QUAL FILTER
# 0  NC_045512.2   3179  .   G   A  49314   PASS  \
# 1  NC_045512.2   6982  .   C   T  20376   PASS
# 2  NC_045512.2   8782  .   C   T  49314   PASS
# 3  NC_045512.2  28144  .   T   C  49314   PASS
#
#                                                INFO
# 0       DP=9759;AF=0.998156;SB=20;DP4=9,1,4563,5178
# 1           DP=619;AF=1.000000;SB=0;DP4=0,0,353,266
# 2        DP=3759;AF=0.997872;SB=5;DP4=2,6,1811,1940
# 3  DP=14107;AF=0.975119;SB=169;DP4=270,71,7818,5938

# %%
# 定义vcf文件路径
vcf_file = '../Folder/DRR286879_filtered.vcf.gz'

# 使用gzip库打开压缩的vcf文件并读取
with gzip.open(vcf_file, 'rb') as f:
    # 跳过以##开头的注释行
    lines = [line.decode('utf-8') for line in f if not line.startswith(b'##')]
    # 获取以#开头的标题行
    header = lines[0].strip().split('\t')
    # 读取剩下的数据行
    data = [line.strip().split('\t') for line in lines[1:]]

# 将数据转换为pandas DataFrame
df = pd.DataFrame(data, columns=header)

# 打印DataFrame
df
# Out:
#         #CHROM    POS ID REF ALT   QUAL FILTER
# 0  NC_045512.2   3179  .   G   A  49314   PASS  \
# 1  NC_045512.2   6982  .   C   T  20376   PASS
# 2  NC_045512.2   8782  .   C   T  49314   PASS
# 3  NC_045512.2  28144  .   T   C  49314   PASS
#
#                                                INFO
# 0       DP=9759;AF=0.998156;SB=20;DP4=9,1,4563,5178
# 1           DP=619;AF=1.000000;SB=0;DP4=0,0,353,266
# 2        DP=3759;AF=0.997872;SB=5;DP4=2,6,1811,1940
# 3  DP=14107;AF=0.975119;SB=169;DP4=270,71,7818,5938

# %%
# 定义vcf文件路径
vcf_file = '../Folder/DRR286879_consensus.fasta.gz'

# 使用gzip库打开压缩的vcf文件并读取
with gzip.open(vcf_file, 'rt') as f:
    # 跳过以##开头的注释行
    lines = [line for line in f if not line.startswith('##')]
    # 获取以#开头的标题行
    header = lines[0].strip().split('\t')
    # 读取剩下的数据行
    data = [line.strip().split('\t') for line in lines[1:]]

# 将数据转换为pandas DataFrame
df = pd.DataFrame(data, columns=header)

gene_seq = df.iloc[0, 0]
gene_seq
# Out:
# '...'

# %% [markdown]
# ## <center>Verification of MAPLE</center>
# ##### <center>MANUAL</center>
#
#
#
# | **Label** | **start time** | **finish time** | **last modified** |
# |:--------------:|:-----------:|:-----------:|:----------------:|
# |   Project 1   |  2023-07-10 |  2023-07-26 |   2023-07-26|
#
#
# &nbsp;
#
# ```python
# # CODE:
# /nfs/research/goldman/zihao/Code/errorsProject_1_P1
# # DATA:
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW
#
# ```
# Path/to/figure: [Click here](#2.Visualization)
#
#
# **Tips：** All the codes need to change the path has been marked in the code as below:
#
#   \# ==================Requires modification==================
#   \# Path to be changed
#   \# ==================Requires modification==================
#
#
# \*path/to/A\*:  means that this file needs to be changed for different needs.

# %% [markdown]
# # <center>Catalog:</center>
# - 1. [Data processing](#1.Data_processing_and_preparation)
#     - [1) Data processing for errorPosition](#1.1_Data_processing_for_errorPosition)
#     - [2) Data processing for allPosition](#1.2_Data_processing_for_allPosition)
#
# &nbsp;
#
# - 2. [Visualization](#2.Visualization)
#     - [1) Density Chart](#1.Density_chart_(python))
#     - [2) Venn Chart](#2.Venn_chart_(R))

# %% [markdown]
# ***
# ***
# # 1.Data_processing_and_preparation
# [Return to Catalog](#Catalog:)
# - **Input**:
# ```python
# *MAPLE output(forErrpos)*: /nfs/research/goldman/zihao/compViridian_2/MAPLE_Part/For_col/MAPLE0.3.2_rateVar_checkingErrors_col_estimatedErrors.txt
#
# *MAPLE input(forAllpos)*: /nfs/research/goldman/zihao/Datas/p2_comp_viridian/2_alignment/Col_MAPLE_format_consensuses.txt
#
# Coverage: /nfs/research/goldman/zihao/Datas/p1/File_5_coverage/Decompress/*.txt
# Annot: /nfs/research/goldman/zihao/Datas/p1/File_5_annot/New_Decompress/*.txt
# ```
# - **Output**:
# ```python
# Count: /nfs/research/goldman/zihao/N_errorsProject_1/Folder_errANDall_dataProcessing/Folder_Checking/outputChecking_*.txt
# Data：/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_errANDall_dataProcessing/BASH_dataProcessing_errAndall.sh
# ```
# ### Code block:
# ```bash
# sh /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_errANDall_dataProcessing/BASH_dataProcessing_errAndall.sh
# ```

# %% [markdown]
# <span style="color:red;">Here's a step-by-step version in case you need it, but in principle just type in the commands above to run them</span>
# ## 1.1_Data_processing_for_errorPosition
# =========================== information For COV ===========================
# - Number of missing IDs: 467
# - Missing IDs saved to:
# ```python
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/errPOS_missing_files_COV.txt
# ```
# =========================== information For ANNOT ===========================
# - There are 2 missing IDs.
# - Missing IDs have been saved to:
# ```python
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/errPOS_missing_files_AF.txt
# ```
#
#
#
# - **Input**:
# ```python
# *MAPLE output*: /nfs/research/goldman/zihao/compViridian_2_P2/MAPLE_Part/For_col/MAPLE0.3.2_rateVar_checkingErrors_col_estimatedErrors.txt
#
# Coverage: /nfs/research/goldman/zihao/Datas/p1/File_5_coverage/Decompress/*.txt
# Annot: /nfs/research/goldman/zihao/Datas/p1/File_5_annot/New_Decompress/*.txt
# ```
# - **Output**:
# ```python
# # Count:
# /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_errPos_dataProcessing/Folder_Checking/outputChecking_*.txt
# # Output_folder：
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/
# # missingID_forCOV:
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/errPOS_missing_files_COV.txt
# # missingID_forANNOT:
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/errPOS_missing_files_AF.txt
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_errPos_dataProcessing/BASH_errPos_dataProcessing.sh
# ```
#
# ### Code block:
# ###### 1) Run the program
# ```bash
# sh /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_errPos_dataProcessing/BASH_errPos_dataProcessing.sh
# ```

# %% [markdown]
# ## 1.2_Data_processing_for_allPosition
#
# =========================== information ===========================
# The number of samples is: 134879/136343
#
# - Missing IDs for CovFileProcessor: 1444 have been logged at
# ```python
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/Folder_Allpos_missingID/missing_ids_cov.txt
# ```
# - Missing IDs for AnnotDataProcessor: 20 have been logged at
# ```python
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/Folder_Allpos_missingID/missing_ids_annot.txt
# ```
#
# - **Input**:
# ```python
# *MAPLE input:* /nfs/research/goldman/zihao/Datas/p2_comp_viridian/2_alignment/Col_MAPLE_format_consensuses.txt
#
# Coverage(folder_path): /nfs/research/goldman/zihao/Datas/p1/File_5_coverage/Decompress/*.txt
# Annot(data_folder): /nfs/research/goldman/zihao/Datas/p1/File_5_annot/New_Decompress/*.txt
# ```
# - **Output**:
# ```python
# # Count:
# /nfs/research/goldman/zihao/N_errorsProject_1/Folder_allPos_dataProcessing/Folder_Checking/outputChecking_*.txt
# # MissingID:
# *log_folder* = /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/Folder_Allpos_missingID
# # *Output_folder*：
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/
# # For COV:
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/folderData_MAPLE_allPos
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_allPos_dataProcessing/CODE_allPos_dataProcessing.py
# ```
# ### Code block:
# ```bash
# bsub -M 5000 -e /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_allPos_dataProcessing/Folder_Checking/dataProcessing_errorChecking.txt -o /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_allPos_dataProcessing/Folder_Checking/dataProcessing_outputChecking.txt 'python3 /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_allPos_dataProcessing/CODE_allPos_dataProcessing.py'
# ```

# %% [markdown]
# ```bash
# bsub -M 20000 -e /nfs/research/goldman/zihao/TEST/dataProcessing_errorChecking.txt -o /nfs/research/goldman/zihao/TEST/dataProcessing_outputChecking.txt 'python3 /nfs/research/goldman/zihao/TEST/CODE_allPos_dataProcessing.py'
# ```

# %% [markdown]
# ## allPos_Forvenn
# - **idea**
#     - Using the COV file obtained in the previous step, add the information for ANNOT
#     - Counting the number of different categories for visualization purposes
# - **input**
# ```python
# # Cov: (from previous step)
# /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder_dataProcessing/folderData_MAPLE_allPos
# # Annot:
# /nfs/research/goldman/zihao/Datas/p1/File_5_annot/New_Decompress
# ```
#
# - **output**
# ```python
# # output_folderMissing_path =
# "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/Folder_missingID"
#
# # missingID: (same as previous step)
# "/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/Folder_missingID/not_found_ids.txt"
#
# # output_dir:
# '/nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/output_calculPercentage.txt'
# ```
#
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_allPos_dataProcessing/CODE_allPos_vennCalcul.py
# ```
#
# ### Code block:
# ```bash
# bsub -M 20000 -e /nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_allPos_dataProcessing/Folder_Checking/vennCalcul_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p1_errorsProject_NEW/Folder2_calculPercentage/output_calculPercentage.txt '/nfs/research/goldman/zihao/Code/errorsProject_1_P1/Folder_allPos_dataProcessing/CODE_allPos_vennCalcul.py'
# ```

# %% [markdown]
# ***
# ***
# # 2.Visualization
# [Return to Catalog](#Catalog:)

# %% [markdown]
# ### 1.Density_chart_(python)
#
# ```python
# dir_d = ["/nfs/research/goldman/zihao/Code/Figure/P1/1_densityChart.ipynb/1.1_densityChart.ipynb"]
#
# ```
#
# ### 2.Venn_chart_(R)
# ```python
# # 1. Prepare the data for plotting
# dir = ["/nfs/research/goldman/zihao/Code/Figure/P1/1-2_prepVenn.ipynb"]
# # 2.1 Plot for Error Positions
# dir_1 = ["/nfs/research/goldman/zihao/Code/Figure/P1/2-1_vennChart_errPos.Rmd"]
# # 2.1 Plot for All Positions
# dir_2 = ["/nfs/research/goldman/zihao/Code/Figure/P1/2-2_vennChart_allPos.Rmd“]
# ```

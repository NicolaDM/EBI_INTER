# %% [markdown]
# ## <center>Analysis of Viridian's assembly</center>
# ##### <center>MANUAL</center>
#
#
#
# | **Label** | **start time** | **finish time** | **last modified** |
# |:--------------:|:-----------:|:-----------:|:----------------:|
# |   Project 1   |  2023-05-16 |  2023-07-26 |   2023-07-26     |
#
#
# &nbsp;
#
# ```python
# # CODE:
# /nfs/research/goldman/zihao/Code/compProject_2_P2
# # DATA:
# OLD: /nfs/research/goldman/zihao/Datas/p2_comp_viridian
#
# After 2.2->: /nfs/research/goldman/zihao/Datas/p2_compViridian_P2
# # Dir/to/plot/figure
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2
# ```
# **Tips：** All the codes need to change the path has been marked in the code as below:
#
#   \# ==================Requires modification==================
#   \# Path to be changed
#   \# ==================Requires modification==================

# %% [markdown]
# # <center>Catalog:</center>
# - 1. Data Preparation
#     - 1.1 [Extract assembled sequences](#1.1_Extract_assembled_sequences)
#     - 1.2 [Split processing](#1.2_Split_processing)
#
# &nbsp;
#
# - 2. Data Processing
#     - 2.1 [Sequence alignment](#2.1_Sequence_alignment)
#     - 2.2 [Combine into one DF](#2.2_Combine_into_one_DF)
#
# &nbsp;
#
# - 3. [Adding information about gene sequences](#3.Adding-info_gene-sequences)
#
# &nbsp;
#
# - 4. [Calculating percentages](#4_calculate_percentage_forAllpos)
#
# &nbsp;
#
# - 5. [Plotting](#5_visualization)
#     - 5.1 [For error positions](#5.1.For_err_pos)
#     - 5.2 [For all positions](#5.2.For_all_pos)

# %% [markdown]
# ---
# # 1. Data Preparation
# ## 1.1_Extract_assembled_sequences
# [Return to Catalog](#Catalog:)

# %% [markdown]
# - **Idea**: Using the IDs of the samples from Colman's assembly running MAPLE, extract the information of the sequences of the corresponding samples from Viridan assembly and save them.
#
# - **Input**: Mr Martin's assembled sequence
# ```python
# /nfs/research/zi/mhunt/Viridian_wf_paper/Vdn_all_ena/Dataset.01/Batches.all_reads/$i.cons.fa.gz
# ```
#
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/1_extract_sequence/
# ```
#
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_1dataPreparation/Folder_1extraceSequences/pg_for_extract.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_1extraceSequences/bash_for_extract.sh
# ```

# %% [markdown]
# ## 1.2_Split_processing
# [Return to Catalog](#Catalog:)
# - **Idea**: To facilitate sequence alignment, sequences are grouped together for subsequent parallelization
#
# - **Input**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/1_extract_sequence
# ```
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/1_extract_sequence/split_files
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_2splitProcessing/pg_splitProcessing.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# bsub -M 20000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_2splitProcessing/Folder_Checking/splitProcessing_errorChecking.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_2splitProcessing/pg_splitProcessing.py'
# ```

# %% [markdown]
# ---
# # 2.Data_Processing
#
# ## 2.1_Sequence_alignment
# [Return to Catalog](#Catalog:)
#
# ### 1. Sequence alignment using MAFFT software
# - **Run the program**:
# ```bash
# bsub sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2sequenceAlignment/Folder_1sequenceAlignment/Aligned.sh
# ```
#
# ### 2. split
#
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2sequenceAlignment/Folder_1sequenceAlignment/pg_splitAligned.py
# ```
# - **Input**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/2_alignment/output_${i}_aligned.fasta
# ```
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/2_alignment/Aligned_split
# ```
# - **Run the program**:
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2sequenceAlignment/Folder_1sequenceAlignment/bash_splitAligned.sh
# ```

# %% [markdown]
# ## 2.2_Combine_into_one_DF
# [Return to Catalog](#Catalog:)
# - **Idea**:
#     - label_masked: The values in this column depend on whether the values in the nucleotide_martin and nucleotide_origin columns are within the specified character lists. If the value in the nucleotide_martin column is among ['-', 'n', 'm', 'r', 'w', 's', 'y', 'k', 'v', 'h', 'd', 'b'], and the value in nucleotide_origin is among ['-', 'n'], then the value in this column will be 1, otherwise 0.
#
#     - label_mar: The values in this column are determined by whether the value in the nucleotide_martin column is within the specified character list. If it's among ['-', 'n', 'm', 'r', 'w', 's', 'y', 'k', 'v', 'h', 'd', 'b'], then the value in this column will be 1, otherwise 0.
#
#     - label_ori: The values in this column depend on whether the value in the nucleotide_origin column is in the list ['-', 'n']. If it is, then the value in this column will be 1, otherwise 0.
#
#     - label_same: The values in this column depend on whether the values in the nucleotide_martin and nucleotide_origin columns are equal and whether they're within the specified character list. If they're equal and are in the list ['-', 'n', 'm', 'r', 'w', 's', 'y', 'k', 'v', 'h', 'd', 'b'], then the value in label_same will be 2. If they're equal but not in the specified list, then the value in label_same will be 1. If they're not equal, then it checks if the value in label_masked, label_mar, or label_ori is 1. If yes, then label_same will be 2, otherwise, it will be 0.
#
# - **Input**:
# ```python
# # Viridian version:
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/2_alignment/Aligned_split/
# # Colman version:
# /nfs/research/goldman/zihao/Datas/p1/File_5_consensus/Decompress/Aligned_split_July_for_MAPLE
# ```
# - **Output**:
# ```python
# output path: /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_2_combination/folderData_combination
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2sequenceAlignment/Folder_2dataCombination/pg_combination.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2sequenceAlignment/Folder_2dataCombination/bash_combination.sh
# ```
# #### Counting missing IDs for all postions: **(After finishing the above run)**
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2sequenceAlignment/Folder_2dataCombination/bash_statMissingID.sh
# ```

# %% [markdown]
# # 3.Adding-info_gene-sequences
# [Return to Catalog](#Catalog:)

# %% [markdown]
# ### Part1_for_all_pos
# - **Input**:
# ```python
# '/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_2_combination/folderData_combination/*.txt'
# df_cov_path = f"/nfs/research/goldman/zihao/Datas/p1/File_5_coverage/Decompress/{id}_coverage.txt"
# df_ann_path = f"/nfs/research/goldman/zihao/Datas/p1/File_5_annot/Decompress/{id}_annot.txt"
#
# ```
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_mergeINFO/folderData_mergeFile/{id}.txt
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_mergeINFO/folderData_missingData/missing_cov_ids_*.txt
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_mergeINFO/folderData_missingData/missing_ann_ids_*.txt
# ```
# - **Address**:
# ```python
# # python:
# /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/pg_mergeAllpos.py
# # bash:
# /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/bash_mergeAllpos.sh
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3addInfo/bash_mergeAllpos.sh
# ```
#
# #### Counting missing IDs for all postions: **(After finishing the above run)**
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3addInfo/bash_statMissingID.sh
# ```
#
# ================ Stat for annot ================
# The number of missing IDs for Annot is: 20
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/missing_ann_ids.txt
# ================ Stat for cov ================
# The number of missing IDs for COV is: 1444
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/missing_cov_ids.txt
# ================ Stat total ================
# The total number of missing IDs is: 1464

# %% [markdown]
# ### Part2_for_err_pos
# - **Input**:
# ```python
# # MAPLE's output: (a_file_path)
# '/nfs/research/goldman/zihao/Datas/p2_compViridian_P3/Folder_mapleOutput/COL_output_modified.txt'
# # Files to be processed: (b_folder_path)
# '/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_mergeINFO/folderData_mergeFile'
# ```
# - **Output**:
# ```python
# output_file_path = '/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_mergeINFO/Folder_errPos/errpos_outputData.txt'
# missing_b_file_path = '/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_mergeINFO/Folder_errPos/errPos_missingFiles.txt'
# missing_rows_file_path = '/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_mergeINFO/Folder_errPos/errPos_missingPos.txt'
#
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3addInfo/pg_mergeErrpos.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3addInfo/Folder_Checking/mergeErrpos_errorChecking.txt -o /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3addInfo/Folder_Checking/mergeErrpos_outputChecking.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3addInfo/pg_mergeErrpos.py'
# ```

# %% [markdown]
# # 4_calculate_percentage_forAllpos
# [Return to Catalog](#Catalog:)
#
# ### Need change:
#
# For venn chart: folder_path -> output for add_infomation (The folder exported in the previous step
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/bash_calculPercentage.sh
# ```

# %% [markdown]
# ### Or enter the commends step by step：
#
# #### 1.For venn chart
#
# ##### diff
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/Folder_Checking/vennDiff_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_diff.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/1.2.1_For_venn_diff.py'
# ```
# ##### masked
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/Folder_Checking/vennMasked_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_masked.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/1.2.2_For_venn_masked.py'
# ```
# ##### same
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/Folder_Checking/vennSame_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_same.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/1.2.3_For_venn_same.py'
# ```
# #### 2.For pie chart
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/Folder_Checking/pieAllpos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultPie_.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_4pourcentage/1.1_Calculate_percentage_all_pos.py'
# ```

# %% [markdown]
# # 5_visualization
# [Return to Catalog](#Catalog:)
#
# - Data preparation + For pie chart: ==========》
# ### 5.1.For_err_pos
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/1.1.pieChart_ERR.ipynb
# ```
#
# - For venn chart: ==========》
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/1.2.vennChart_ERR.Rmd
# ```
# ### 5.2.For_all_pos
#     - 1.Extract data from the following output
# ```python
# # 1.1 forVenn_diff
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_diff.txt
# # 1.2 forVenn_masked
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_masked.txt
# # 1.3 forVenn_same
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_same.txt
# # 2 forPie
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultPie.txt
# ```
#     - 2.Inputting data into ipy for processing
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/2.1.pieChart_ALL.ipynb
# ```
#
# - For venn chart: ==========》
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/2.2.vennChart_ALL.Rmd
# ```
#
# ### Final - Combination:
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/FINAL-plotVenn.vsdx
# ```

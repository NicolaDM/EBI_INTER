# %% [markdown]
# ## <center>Comparative validation of MAPLE and Viridian</center>
# ##### <center>MANUAL</center>
#
#
#
# | **Label** | **start time** | **finish time** | **last modified** |
# |:--------------:|:-----------:|:-----------:|:----------------:|
# |   Project 1   |  2023-05-16 |  2023-07-26 |   2023-09-12     |
#
#
# &nbsp;
#
# ```python
# # CODE:
# /nfs/research/goldman/zihao/Code/compProject_2_P2
# # DATA:
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2
# # Dir/to/plot/figure
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2
# ```
# **Tips：** All the codes need to change the path has been marked in the code as below:
#
#   \# ==================Requires modification==================
#   \# Path to be changed
#   \# ==================Requires modification==================

# %% [markdown]
# # <center>Catalog:</center>
# - 1. Data Preparation
#     - 1.1 [Extract assembled sequences](#1.1_Extract_assembled_sequences)
#     - 1.2 [Split processing](#1.2_Split_processing)
#     - 1.3 [Sequence alignment](#1.3_Sequence_alignment)
#
# &nbsp;
#
# - 2. [Data Processing](#2.Adding-info_gene-sequences)
#
# &nbsp;
#
# - 3. [Calculating percentages](#3_calculate_infomations)
#
# &nbsp;
#
# - 4. [Plotting](#4_visualization)
#     - 4.1 [For error positions](#4.1.For_err_pos)
#     - 4.2 [For all positions](#4.2.For_all_pos)

# %% [markdown]
# ---
# # 1. Data Preparation
# ## 1.1_Extract_assembled_sequences
# [Return to Catalog](#Catalog:)

# %% [markdown]
# - **Idea**: Using the IDs of the samples from Colman's assembly running MAPLE, extract the information of the sequences of the corresponding samples from Viridan assembly and save them.
#
# - **Input**: Mr Martin's assembled sequence (Viridian assemblies)
# ```python
# /nfs/research/zi/mhunt/Viridian_wf_paper/Vdn_all_ena/Dataset.01/Batches.all_reads/$i.cons.fa.gz
# ```
#
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_1_dataPrep/folderData_extractSequence
# ```
#
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_1extraceSequences/pg_for_extract.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_1extraceSequences/bash_for_extract.sh
# ```

# %% [markdown]
# ## 1.2_Split_processing
# [Return to Catalog](#Catalog:)
# - **Idea**: To facilitate sequence alignment, sequences are grouped together for subsequent parallelization
#
# - **Input**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_1_dataPrep/folderData_extractSequence
# ```
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_1_dataPrep/folderData_extractSequence/split_files
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_2splitProcessing/pg_splitProcessing.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# bsub -M 20000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_2splitProcessing/Folder_Checking/splitProcessing_errorChecking.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_2splitProcessing/pg_splitProcessing.py'
# ```

# %% [markdown]
# ## 1.3_Sequence_alignment
# [Return to Catalog](#Catalog:)
#
# ### 1. Sequence alignment using MAFFT software
# - **Run the program**:
# ```bash
# bsub sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_3sequenceAlignment/Aligned.sh
# ```
#
# ### 2. split
#
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_3sequenceAlignment/pg_splitAligned.py
# ```
# - **Input**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_1_dataPrep/Folder_alignment/output_${i}_aligned.fasta
# ```
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_1_dataPrep/Folder_alignment/folderData_alignedSplit
# ```
# - **Run the program**:
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_1dataPreparation/Folder_3sequenceAlignment/bash_splitAligned.sh
# ```

# %% [markdown]
# ---
# # 2.Adding-info_gene-sequences
# [Return to Catalog](#Catalog:)
# - **Idea**:
#     - label_masked: The values in this column depend on whether the values in the nucleotide_martin and nucleotide_origin columns are within the specified character lists. If the value in the nucleotide_martin column is among ['-', 'n', 'm', 'r', 'w', 's', 'y', 'k', 'v', 'h', 'd', 'b'], and the value in nucleotide_origin is among ['-', 'n'], then the value in this column will be 1, otherwise 0.
#
#     - label_mar: The values in this column are determined by whether the value in the nucleotide_martin column is within the specified character list. If it's among ['-', 'n', 'm', 'r', 'w', 's', 'y', 'k', 'v', 'h', 'd', 'b'], then the value in this column will be 1, otherwise 0.
#
#     - label_ori: The values in this column depend on whether the value in the nucleotide_origin column is in the list ['-', 'n']. If it is, then the value in this column will be 1, otherwise 0.
#
#     - label_same: The values in this column depend on whether the values in the nucleotide_martin and nucleotide_origin columns are equal and whether they're within the specified character list. If they're equal and are in the list ['-', 'n', 'm', 'r', 'w', 's', 'y', 'k', 'v', 'h', 'd', 'b'], then the value in label_same will be 2. If they're equal but not in the specified list, then the value in label_same will be 1. If they're not equal, then it checks if the value in label_masked, label_mar, or label_ori is 1. If yes, then label_same will be 2, otherwise, it will be 0.
#
#     - After that, add information about ANNOT and COV.
#
# - **Input**:
#
# ```python
# # Aligned sequences:
# ## Viridian version:
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_1_dataPrep/Folder_alignment/folderData_alignedSplit/
# ## Colman version:
# /nfs/research/goldman/zihao/Datas/p1/File_5_consensus/Decompress/Aligned_split_July_for_MAPLE
#
# # Information about ANNOT and COV.
# ## For Coverage:
# /nfs/research/goldman/zihao/Datas/p1/File_5_coverage/Decompress/{id}_coverage.txt
# ## For Annotation:
# /nfs/research/goldman/zihao/Datas/p1/File_5_annot/Decompress/{id}_annot.txt
# ```
# - **Output**:
# ```python
# output path: /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_2_combination/folderData_addInfo
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2addInfo/pg_mergeAllpos.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2addInfo/bash_combination.sh
# ```
# #### Counting missing IDs for all postions: **(After finishing the above run)**
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_2addInfo/bash_statMissingID.sh
# ```
# ================ Stat for combination ================
# The number of missing IDs on merge is: 0
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_2_combination/missingFile_ids.txt
# ================ Stat for annot ================
# The number of missing IDs for Annot is: 20
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_2_combination/missing_ann_ids.txt
# ================ Stat for cov ================
# The number of missing IDs for COV is: 1444
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_2_combination/missing_cov_ids.txt
# ================ Stat total ================
# The total number of missing IDs is: 1464

# %% [markdown]
# # 3_calculate_infomations
# [Return to Catalog](#Catalog:)
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/bash_calcul.sh
# ```
# ### Or enter the commends step by step：
# ### Part1_for_err_pos
# - **Input**:
# ```python
# # MAPLE's output: (a_file_path)
# '/nfs/research/goldman/zihao/Datas/p2_compViridian_P3/Folder_mapleOutput/COL_output_modified.txt'
# # Files to be processed: (b_folder_path)
# "/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_2_combination/folderData_addInfo"
# ```
# - **Output**:
# ```python
# output_file_path = '/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/errPos/errpos_outputData.txt'
# missing_b_file_path = '/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/errPos/errPos_missingFiles.txt'
# missing_rows_file_path = '/nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/errPos/errPos_missingPos.txt'
#
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/errPos.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/Folder_Checking/errPos_errorChecking.txt -o /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/Folder_Checking/errPos_outputChecking.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/errPos.py'
# ```

# %% [markdown]
# ### Part2_for_all_pos
# #### 1.For venn chart
# ##### diff
# ```bash
# bsub -M 5000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/Folder_Checking/vennDiff_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/allPos/allPos_vennDiff.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/allPOS_diff.py'
# ```
# ##### masked
# ```bash
# bsub -M 5000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/Folder_Checking/vennMasked_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/allPos/allPos_vennMasked.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/allPOS_masked.py'
# ```
# ##### same
# ```bash
# bsub -M 5000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/Folder_Checking/vennSame_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/allPos/allPos_vennSame.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/allPOS_same.py'
# ```
# #### 2.For pie chart
# ```bash
# bsub -M 5000 -e /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/Folder_Checking/pieAllpos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/allPos/allPos_pie.txt 'python3 /nfs/research/goldman/zihao/Code/compProject_2_P2/Folder_3calculing/allPOS_pie.py'
# ```

# %% [markdown]
# # 4_visualization
# [Return to Catalog](#Catalog:)
#
# - Data preparation + For pie chart: ==========》
# ### 4.1.For_err_pos
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/1.1.pieChart_ERR.ipynb
# ```
#
# - For venn chart: ==========》
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/1.2.vennChart_ERR.Rmd
# ```
# ### 4.2.For_all_pos
#     - 1.Extract data from the following output
# ```python
# # 1.1 forVenn_diff
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/allPos/allPos_vennDiff.txt
# # 1.2 forVenn_masked
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/allPos/allPos_vennMasked.txt
# # 1.3 forVenn_same
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/allPos/allPos_vennSame.txt
# # 2 forPie
# /nfs/research/goldman/zihao/Datas/p2_compViridian_P2/Folder_3_calculForPLOT/allPos/allPos_pie.txt
# ```
#     - 2.Inputting data into ipy for processing
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/2.1.pieChart_ALL.ipynb
# ```
#
# - For venn chart: ==========》
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/2.2.vennChart_ALL.Rmd
# ```
#
# ### Final - Combination:
# ```python
# /nfs/research/goldman/zihao/Code/jupyterLab/Project_2_vircolComp/1.pievennPlot_P2/FINAL-plotVenn.vsdx
# ```

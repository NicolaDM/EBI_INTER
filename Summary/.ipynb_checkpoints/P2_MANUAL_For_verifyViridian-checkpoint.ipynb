# %% [markdown]
# # TODO:
# - 代码上标出来哪里需要改
# - 出图

# %% [markdown]
# ## <center>Analysis of Viridian's assembly</center>
# ##### <center>MANUAL</center>
#
#
#
# | **Label** | **start time** | **finish time** | **last modified** |
# |:--------------:|:-----------:|:-----------:|:----------------:|
# |   Project 1   |  2023-05-16 |  2023-07-26 |   2023-07-26     |
#
#
# &nbsp;
#
# ```python
# # CODE:
# ## Until 2.3:
# /nfs/research/goldman/zihao/compViridian_2_P2
# ## 2.3 and after:
# /nfs/research/goldman/zihao/N_compViridian_2_P2
# # DATA:
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian
# # Path/to/figure
# /nfs/research/goldman/zihao/code/EBI_INTER/Project_2_vircolComp/1.pievenn_Plot_P2
# ```
# **Tips：** All the codes need to change the path has been marked in the code as below:
#
#   \# ==================Requires modification==================
#   \# Path to be changed
#   \# ==================Requires modification==================

# %% [markdown]
# # <center>Catalog:</center>
# - 1. Data Preparation
#     - 1.1 [Extract assembled sequences](#1.1_Extract_assembled_sequences)
#     - 1.2 [Split processing](#1.2_Split_processing)
#
# &nbsp;
#
# - 2. Data Processing
#     - 2.1 [Sequence alignment](#2.1_Sequence_alignment)
#     - 2.2 [Combine into one DF](#2.2_Combine_into_one_DF)
#     - 2.3 [Adding info](#2.3_add_infomation(sb_af))
#
# &nbsp;
#
# - 3. Calculating percentages
#     - 3.1 [Calculate percentage](#3_calculate_percentage_forAllpos)
#
# &nbsp;
# - 4. [Plotting](#4_visualization)
#     - 4.1 [For error positions](#4.1.For_err_pos)
#     - 4.2 [For all positions](#4.2.For_all_pos)

# %% [markdown]
# ---
# # 1. Data Preparation
# ## 1.1_Extract_assembled_sequences
# [Return to Catalog](#Catalog:)

# %% [markdown]
# - **Input**: Mr Martin's assembled sequence
# - **Output**:
#     - Folder: /nfs/research/goldman/zihao/Datas/p2_comp_viridian/1_extract_sequence/
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/compViridian_2/1_extract_sequence/pg_for_extract.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/compViridian_2/1_extract_sequence/bash_for_extract.sh
# ```

# %% [markdown]
# ## 1.2_Split_processing
# [Return to Catalog](#Catalog:)

# %% [markdown]
# - **Input**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/1_extract_sequence
# ```
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/1_extract_sequence/split_files
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/compViridian_2/1_extract_sequence/pg_for_extract_2.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# bsub -M 20000 -e /nfs/research/goldman/zihao/compViridian_2/1_extract_sequence/pg_for_extract_2_errorChecking_error.txt 'python3 /nfs/research/goldman/zihao/compViridian_2/1_extract_sequence/pg_for_extract_2.py'
# ```

# %% [markdown]
# ---
# # 2.Data_Processing
#
# ## 2.1_Sequence_alignment
# [Return to Catalog](#Catalog:)
#
# ### 1. Sequence alignment using MAFFT software
# - **Run the program**:
# ```bash
# bsub sh /nfs/research/goldman/zihao/compViridian_2/2_alignment/Aligned.sh
# ```
#
# ### 2. split
#
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/errorsProject_1/Part1_2_for_assemble/Part2_Compare/2.MAPLE_part.py
# ```
#
#
# - **Output**:
# ```python
# save path: /nfs/research/goldman/zihao/Datas/p1/File_5_consensus/Decompress/Aligned_split_May
# ```
# - **Run the program**:
# ```bash
# sh bash_for_split_aligned.sh
# ```

# %% [markdown]
# ## 2.2_Combine_into_one_DF
# [Return to Catalog](#Catalog:)

# %% [markdown]
# - **Input**:
# ```python
# # Viridian version:
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/2_alignment/Aligned_split/
# # Colman version:
# /nfs/research/goldman/zihao/Datas/p1/File_5_consensus/Decompress/Aligned_split_May/
# ```
# - **Output**:
# ```python
# output path: /nfs/research/goldman/zihao/Datas/p2_comp_viridian/3_combination
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/compViridian_2/3_combination/pg_combination.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/compViridian_2/3_combination/bash_combination.sh
# ```

# %% [markdown]
# ## 2.3_add_infomation(sb_af)
# [Return to Catalog](#Catalog:)

# %% [markdown]
# ### Part1_for_all_pos
# - **Input**:
# ```python
# '/nfs/research/goldman/zihao/Datas/p2_comp_viridian/3_combination/*.txt'
# df_cov_path = f"/nfs/research/goldman/zihao/Datas/p1/File_5_coverage/Decompress/{id}_coverage.txt"
# df_ann_path = f"/nfs/research/goldman/zihao/Datas/p1/File_5_annot/Decompress/{id}_annot.txt"
#
# ```
# - **Output**:
# ```python
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/Folder_mergeFile/{id}.txt
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/Folder_mergeFile/missing_cov_ids_*.txt
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/Folder_mergeFile/missing_ann_ids_*.txt
# ```
# - **Address**:
# ```python
# # python:
# /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/pg_mergeAllpos.py
# # bash:
# /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/bash_mergeAllpos.sh
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/bash_mergeAllpos.sh
# ```
#
# #### Counting missing IDs for all postions: **(After finishing the above run)**
# ```bash
# sh /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/bash_statMissingID.sh
# ```

# %% [markdown]
# ### Part2_for_err_pos
# - **Input**:
# ```python
# # MAPLE's output: (a_file_path)
# '/nfs/research/goldman/zihao/errorsProject_1/MAPLE/new_version_MAY/output_modified.txt'
# # Files to be processed: (b_folder_path)
# '/nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/Folder_mergeFile'
# ```
# - **Output**:
# ```python
# output_file_path = '/nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/errpos_outputData.txt'
# missing_b_file_path = '/nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/Folder_missingData/errPos_missingFiles.txt'
# missing_rows_file_path = '/nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_3_mergeINFO/Folder_missingData/errPos_missingPos.txt'
#
# ```
# - **Address**:
# ```python
# /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/pg_mergeErrpos.py
# ```
#
# ### Code block:
# ###### Run the program
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/Folder_Checking/mergeErrpos_errorChecking.txt -o /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/Folder_Checking/mergeErrpos_outputChecking.txt 'python3 /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_3addInfo/pg_mergeErrpos.py'
# ```

# %% [markdown]
# ## 3_calculate_percentage_forAllpos
# [Return to Catalog](#Catalog:)
#
# ### Need change:
#
# For venn chart: folder_path -> output for add_infomation (The folder exported in the previous step
# ### Code block:
# ###### Run the program
# ```bash
# sh /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/bash_calculPercentage.sh
# ```

# %% [markdown]
# ### Or enter the commends step by step：
#
# #### 1.For venn chart
#
# ##### diff
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/Folder_Checking/vennDiff_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_diff.txt 'python3 /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/1.2.1_For_venn_diff.py'
# ```
# ##### masked
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/Folder_Checking/vennMasked_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_masked.txt 'python3 /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/1.2.2_For_venn_masked.py'
# ```
# ##### same
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/Folder_Checking/vennSame_allPos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_same.txt 'python3 /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/1.2.3_For_venn_same.py'
# ```
# #### 2.For pie chart
# ```bash
# bsub -M 2000 -e /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/Folder_Checking/pieAllpos_errorChecking.txt -o /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultPie_.txt 'python3 /nfs/research/goldman/zihao/N_compViridian_2_P2/Folder_4pourcentage/1.1_Calculate_percentage_all_pos.py'
# ```

# %% [markdown]
# ## 4_visualization
# [Return to Catalog](#Catalog:)
#
# - Data preparation + For pie chart: ==========》
# ### 4.1.For_err_pos
# ```python
# /nfs/research/goldman/zihao/code/EBI_INTER/Project_2_vircolComp/1.pievenn_Plot_P2/4.1_plot_errPos.ipynb
# ```
# ### 4.2.For_all_pos
#     - 1.Extract data from the following output
# ```python
# # 1.1 forVenn_diff
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_diff.txt
# # 1.2 forVenn_masked
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_masked.txt
# # 1.3 forVenn_same
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultVenn_same.txt
# # 2 forPie
# /nfs/research/goldman/zihao/Datas/p2_comp_viridian/Folder_4_percentage/allPos_resultPie.txt
# ```
#     - 2.Inputting data into ipy for processing
# ```python
# /nfs/research/goldman/zihao/code/EBI_INTER/Project_2_vircolComp/1.pievenn_Plot_P2/4.2.plot_allPos.ipynb
# ```
#
# - For venn chart: ==========》
# ```python
# /nfs/research/goldman/zihao/code/EBI_INTER/Project_2_vircolComp/1.pievenn_Plot_P2/PLOT/Venn_ALL.Rmd
# /nfs/research/goldman/zihao/code/EBI_INTER/Project_2_vircolComp/1.pievenn_Plot_P2/PLOT/Venn_ERR.Rmd
# ```
